# %%
# Import the random module.
import random

# %%
random.randint(-90, 90)
# Out:
# 18

# %%
random.random()
# Out:
# 0.12507648644315972

# %%
random_number = random.randint(-90, 90) + random.random()
random_number
# Out:
# 39.4823049590163

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1
latitudes
# Out:
# [33.006683345119924,
#  -6.471458649887694,
#  -73.68717145243103,
#  47.95665110347604,
#  20.027635064717995,
#  -86.90289538732418,
#  81.16673782190274,
#  -79.86163528218601,
#  0.12400102748207043,
#  75.41110531752025]

# %%
random.randrange(-90, 90, step=1)
# Out:
# 79

# %%
random.randrange(-90, 90, step=3)
# Out:
# -63

# %%
random.uniform(-90, 90)
# Out:
# -81.33170409554495

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# -76.28360428444383

# %%
np.random.uniform(low=-90, high=90)
# Out:
# 61.57039002983552

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([-87.36087853, -34.33943107,  31.5721671 ,  27.28267762,
#         14.36877309,  24.53713989, -31.01484962,   2.90152309,
#        -29.54524445,  55.58651765,  70.14789381, -61.01915981,
#         77.00560599, -84.35975508, -68.93260806, -85.15145114,
#         88.94567791,  59.16154731, -37.17900382, -50.96947875,
#        -32.99393992,  49.92306627, -44.18171297, -77.16191187,
#         58.04600726, -75.9756528 , -33.4189998 , -68.68582478,
#        -75.00854009,  42.89735792, -13.35743253,  -5.74206283,
#         60.48861863,  12.55786757,  52.08784136, -23.15264058,
#         20.86069504,  71.58082747, -73.18157865, -23.68087684,
#         53.49307934,   3.93239462, -27.38809987, -35.58970596,
#         75.26402636,  80.86819108, -74.24305182, -24.51301865,
#        -49.6881889 ,  35.73330513])

# %%
# %timeit
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 13.5 µs ± 136 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.78 ms ± 205 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    for x in latitudes:
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 133 ns ± 33.4 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
